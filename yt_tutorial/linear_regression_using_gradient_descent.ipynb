# %% [markdown]
# # Linear Regression using Gradient Descent in Python - Machine Learning Basics
# [GitHub](https://github.com/chasinginfinity/ml-from-scratch/tree/master/02%20Linear%20Regression%20using%20Gradient%20Descent)
#  |
# [Medium](https://towardsdatascience.com/linear-regression-using-gradient-descent-97a6c8700931)
#  |
#  [Youtube](https://www.youtube.com/watch?v=4PHI11lX11I)

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv('data.csv')
x = data.iloc[:, 0] # column 1
y = data.iloc[:, 1] # column 2
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### The Gradient Descent Algorithm
# ![image.png](attachment:82c4a478-4c54-4210-b2b4-660771a68a5c.png)

# %%
# Building the model
m = 0
c = 0

L = 0.0001 # learning rate
epochs = 1000 # iterations

n = float(len(x))

for i in range(n):
    y_pred = m*x + c
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

# %%
# Making predictions
